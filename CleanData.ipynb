# %%
# Import stuff
import pandas as pd
import random

# %%
#Read the CSV File into df
df = pd.read_csv('./emed_careers_eu.csv')
df
# Out:
#                              category                      company_name  \
# 0                   Clinical Research                    PPD GLOBAL LTD
# 1                             Science                      AL Solutions
# 2                             Science            Seltek Consultants Ltd
# 3      Data Management and Statistics     Docs International UK Limited
# 4                             Science   Hyper Recruitment Solutions Ltd
# ...                               ...                               ...
# 39769                             NaN                               NaN
# 39770                             NaN                               NaN
# 39771                             NaN                               NaN
# 39772                             NaN                               NaN
# 39773                             NaN                               NaN
#
#                                          job_description  \
# ...

# %%
df.category.value_counts()
# Out:
# Pharmaceutical, Healthcare and Medical Sales    7594
# Clinical Research                               5227
# Science                                         4831
# Manufacturing & Operations                      3802
# Regulatory Affairs                              1984
# Pharmaceutical Marketing                        1750
# Data Management and Statistics                  1392
# Quality-assurance                               1150
# Medical Information and Pharmacovigilance       1011
# Medical Affairs / Pharmaceutical Physician       772
# Switzerland                                       99
# UK                                                99
# Germany                                           93
# science                                           59
# Pharmacy                                          47
# Italy                                             36
# Spain                                             31
# France                                            23
# ...

# %%
clean = df.drop(df[df.category != 'Pharmaceutical, Healthcare and Medical Sales'].index)
clean
# Out:
#                                            category  \
# 17     Pharmaceutical, Healthcare and Medical Sales
# 35     Pharmaceutical, Healthcare and Medical Sales
# 46     Pharmaceutical, Healthcare and Medical Sales
# 58     Pharmaceutical, Healthcare and Medical Sales
# 66     Pharmaceutical, Healthcare and Medical Sales
# ...                                             ...
# 29835  Pharmaceutical, Healthcare and Medical Sales
# 29865  Pharmaceutical, Healthcare and Medical Sales
# 29918  Pharmaceutical, Healthcare and Medical Sales
# 29963  Pharmaceutical, Healthcare and Medical Sales
# 29989  Pharmaceutical, Healthcare and Medical Sales
#
#                        company_name  \
# 17                Kirkham Young Ltd
# 35                Kirkham Young Ltd
# 46                  BMS Performance
# 58        Silchester Associates Ltd
# 66      ID Search and Selection Ltd
# ...                             ...
# 29835      Evolve Selection Limited
# 29865           NonStop Recruitment
# ...

# %%
views = []
saved = []
for x in range(7594):
  views.append(random.randint(0,2579))
  saved.append(random.randint(0,500))
    
clean['views'] = views
clean['saved'] = saved
clean.head()
# Out:
#                                         category  \
# 17  Pharmaceutical, Healthcare and Medical Sales
# 35  Pharmaceutical, Healthcare and Medical Sales
# 46  Pharmaceutical, Healthcare and Medical Sales
# 58  Pharmaceutical, Healthcare and Medical Sales
# 66  Pharmaceutical, Healthcare and Medical Sales
#
#                     company_name  \
# 17             Kirkham Young Ltd
# 35             Kirkham Young Ltd
# 46               BMS Performance
# 58     Silchester Associates Ltd
# 66   ID Search and Selection Ltd
#
#                                       job_description  \
# 17  Business Development Manager - Medical IT\nThi...
# 35   Sales Specialist - Interventional Cardiac Dev...
# 46   This is a fantastic opportunity for a strateg...
# 58  Our client is a leading manufacturer, wholesal...
# 66  Our client is a boutique agency delivering hig...
#
#                     job_title   job_type    location  post_date  \
# ...

# %%
clean.to_csv(r'./clean.csv')
