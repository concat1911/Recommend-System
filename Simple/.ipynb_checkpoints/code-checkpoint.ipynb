# %%
import pandas as pd
# pd.__version__

# %%
#Read the CSV File into df
df = pd.read_csv('../clean.csv')
df.head()
# Out:
#    Unnamed: 0                                      category  \
# 0          17  Pharmaceutical, Healthcare and Medical Sales
# 1          35  Pharmaceutical, Healthcare and Medical Sales
# 2          46  Pharmaceutical, Healthcare and Medical Sales
# 3          58  Pharmaceutical, Healthcare and Medical Sales
# 4          66  Pharmaceutical, Healthcare and Medical Sales
#
#                    company_name  \
# 0             Kirkham Young Ltd
# 1             Kirkham Young Ltd
# 2               BMS Performance
# 3     Silchester Associates Ltd
# 4   ID Search and Selection Ltd
#
#                                      job_description  \
# 0  Business Development Manager - Medical IT\nThi...
# 1   Sales Specialist - Interventional Cardiac Dev...
# 2   This is a fantastic opportunity for a strateg...
# 3  Our client is a leading manufacturer, wholesal...
# 4  Our client is a boutique agency delivering hig...
#
#                    job_title   job_type    location  post_date salary_offered  \
# 0          Sales Specialist   Permanent          UK  4/16/2018            NaN
# 1          Sales Specialist   Permanent      London  4/12/2018            Neg
# 2     Regional Sales Manager  Permanent      Europe  4/16/2018            NaN
# 3  Pharmaceutical Wholesale   Permanent  Birmingham  4/11/2018            NaN
# 4    Senior Account Manager   Permanent  South East  4/13/2018            NaN
#
#    views
# 0   1181
# 1    555
# 2    635
# 3   2018
# 4   1099

# %%
#Calculate the number of views garnered by the 70th percentile job
m = df['views'].quantile(0.70)
m
#We can see that only 30% of the movies have gained more than 1788 views. Therefore, our value of m is 1788
# Out:
# 1788.0

# %%
data = df

# %%
# Calculate C
C = df['views'].mean()
C
# Out:
# 1279.469581248354

# %%
# Function to compute the Job weighted views for each position
def weighted_rating(x, m=m, C=C):
    v = x['views']
    R = x['views_average']
    # Compute the weighted score
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
# Compute the score using the weighted_rating function defined above
data['score'] = data.apply(weighted_rating, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-83d7cfa305ef> in <module>
#       1 # Compute the score using the weighted_rating function defined above
# ----> 2 data['score'] = data.apply(weighted_rating, axis=1)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# ~/.local/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# <ipython-input-12-117e65f845dd> in weighted_rating(x, m, C)
#       2 def weighted_rating(x, m=m, C=C):
#       3     v = x['views']
# ----> 4     R = x['vote_average']
#       5     # Compute the weighted score
#       6     return (v/(v+m) * R) + (m/(m+v) * C)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4742                     raise InvalidIndexError(key)
#    4743                 else:
# -> 4744                     raise e1
#    4745             except Exception:  # pragma: no cover
#    4746                 raise e1
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('vote_average', 'occurred at index 0')

# %%
#Sort movies in descending order of their scores
q_movies = q_movies.sort_values('score', ascending=False)

#Print the top 25 movies
q_movies[['title', 'vote_count', 'vote_average', 'score', 'runtime']].head(25)
# Out:
#                                  title  vote_count  vote_average     score  \
# 10309      Dilwale Dulhania Le Jayenge       661.0           9.1  8.855148
# 314           The Shawshank Redemption      8358.0           8.5  8.482863
# 834                      The Godfather      6024.0           8.5  8.476278
# 40251                       Your Name.      1030.0           8.5  8.366584
# 12481                  The Dark Knight     12269.0           8.3  8.289115
# 2843                        Fight Club      9678.0           8.3  8.286216
# 292                       Pulp Fiction      8670.0           8.3  8.284623
# 522                   Schindler's List      4436.0           8.3  8.270109
# 23673                         Whiplash      4376.0           8.3  8.269704
# 5481                     Spirited Away      3968.0           8.3  8.266628
# 2211                 Life Is Beautiful      3643.0           8.3  8.263691
# 1178            The Godfather: Part II      3418.0           8.3  8.261335
# 1152   One Flew Over the Cuckoo's Nest      3001.0           8.3  8.256051
# 1176                            Psycho      2405.0           8.3  8.245381
# 351                       Forrest Gump      8147.0           8.2  8.184252
# 1184       Once Upon a Time in America      1104.0           8.3  8.183804
# 1154           The Empire Strikes Back      5998.0           8.2  8.178656
# 18465                 The Intouchables      5410.0           8.2  8.176357
# 289             Leon: The Professional      4293.0           8.2  8.170276
# 3030                    The Green Mile      4166.0           8.2  8.169381
# 1170                        GoodFellas      3211.0           8.2  8.160414
# 2216                American History X      3120.0           8.2  8.159278
# 1161                      12 Angry Men      2130.0           8.2  8.140785
# 9698              Howl's Moving Castle      2049.0           8.2  8.138499
# 2884                 Princess Mononoke      2041.0           8.2  8.138264
#
#        runtime
# 10309    190.0
# 314      142.0
# 834      175.0
# 40251    106.0
# 12481    152.0
# 2843     139.0
# 292      154.0
# 522      195.0
# 23673    105.0
# 5481     125.0
# 2211     116.0
# 1178     200.0
# 1152     133.0
# 1176     109.0
# 351      142.0
# 1184     229.0
# 1154     124.0
# 18465    112.0
# 289      110.0
# 3030     189.0
# 1170     145.0
# 2216     119.0
# 1161      96.0
# 9698     119.0
# 2884     134.0
